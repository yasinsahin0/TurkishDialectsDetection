# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import librosa
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation , Dropout

import IPython.display as ipd

# %%
path = 'urban'

df = pd.read_csv('urban/UrbanSound8K.csv')
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# 1           2  children_playing
# 2           2  children_playing
# 3           2  children_playing
# 4           2  children_playing
# ...       ...               ...
# 8727        1          car_horn
# 8728        1          car_horn
# 8729        1          car_horn
# 8730        1          car_horn
# 8731        1          car_horn
#
# [8732 rows x 8 columns]

# %%
def features_extract(file):
    audio,sample_rate = librosa.load(file_name,res_type='kaiser_fast')
    feature = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=50)
    scaled_feature = np.mean(feature.T,axis=0)
    return scaled_feature

extracted = []

for index_num,row in tqdm(df.iterrows()):
    file_name = os.path.join(os.path.abspath(path),'fold'+str(row["fold"])+'/',str(row['slice_file_name'])) 
    final_class_labels = row['class']   
    data= features_extract(file_name)    
    extracted.append([data,final_class_labels])
# Out:
# 3553it [02:13, 24.45it/s]/Users/yasinsahin/miniconda3/envs/ml/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# 8323it [05:30, 32.98it/s]/Users/yasinsahin/miniconda3/envs/ml/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   return f(*args, **kwargs)
# /Users/yasinsahin/miniconda3/envs/ml/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   return f(*args, **kwargs)
# 8732it [05:46, 25.21it/s]

# %%
ext_df = pd.DataFrame(extracted,columns=['feature','class'])
ext_df
# Out:
#                                                 feature             class
# 0     [-218.18938, 71.38549, -131.49442, -52.25892, ...          dog_bark
# 1     [-425.05234, 110.67095, -54.192833, 62.045406,...  children_playing
# 2     [-459.82623, 122.82864, -47.908062, 53.302677,...  children_playing
# 3     [-414.82184, 102.94826, -36.656853, 54.170742,...  children_playing
# 4     [-447.60776, 115.08627, -53.74607, 61.55309, 1...  children_playing
# ...                                                 ...               ...
# 8727  [-399.52393, 136.84413, -51.977036, 37.014854,...          car_horn
# 8728  [-347.32773, 87.53586, -46.2994, 52.748062, -3...          car_horn
# 8729  [-304.84702, 112.69567, -47.21992, 37.061134, ...          car_horn
# 8730  [-345.06885, 126.78658, -56.18254, 36.07703, -...          car_horn
# 8731  [-316.331, 95.86536, -38.176315, 47.640114, -7...          car_horn
#
# [8732 rows x 2 columns]

# %%
x = np.array(ext_df['feature'].tolist())
y = np.array(ext_df['class'].tolist())

# %%
le = LabelEncoder()

y = to_categorical(le.fit_transform(y))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

print("Number of training samples = ", x_train.shape[0])
print("Number of testing samples = ",x_test.shape[0])
# Out:
# Number of training samples =  6985
# Number of testing samples =  1747

# %%
num_labels = y.shape[1]
model = Sequential()

model.add(Dense(128, input_shape=(50,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(128))

model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
# Out:
# 2022-05-29 22:48:48.365167: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-29 22:48:48.365732: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               6528
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 10)                1290
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 139,530
# Trainable params: 139,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])

# %%
num_epochs = 150
num_batch_size = 32

model.fit(
          x_train, 
          y_train, 
          batch_size=num_batch_size, 
          epochs=num_epochs,
          validation_data=(x_test, y_test),
         )
# Out:
# Epoch 1/150
# 2022-05-29 22:48:54.529517: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-29 22:48:54.765560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - ETA: 0s - loss: 7.6494 - accuracy: 0.2302
# 2022-05-29 22:48:58.982123: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - 5s 11ms/step - loss: 7.6494 - accuracy: 0.2302 - val_loss: 1.9711 - val_accuracy: 0.2931
# Epoch 2/150
# 219/219 [==============================] - 2s 9ms/step - loss: 2.1524 - accuracy: 0.3208 - val_loss: 1.9256 - val_accuracy: 0.3057
# Epoch 3/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.8044 - accuracy: 0.3822 - val_loss: 1.8442 - val_accuracy: 0.3457
# Epoch 4/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.6917 - accuracy: 0.4125 - val_loss: 1.7329 - val_accuracy: 0.4390
# Epoch 5/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.5862 - accuracy: 0.4563 - val_loss: 1.6886 - val_accuracy: 0.4396
# Epoch 6/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.5313 - accuracy: 0.4676 - val_loss: 1.5957 - val_accuracy: 0.4940
# Epoch 7/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.4743 - accuracy: 0.4899 - val_loss: 1.5441 - val_accuracy: 0.5009
# Epoch 8/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.3964 - accuracy: 0.5162 - val_loss: 1.4949 - val_accuracy: 0.5094
# Epoch 9/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.3618 - accuracy: 0.5294 - val_loss: 1.4338 - val_accuracy: 0.5512
# Epoch 10/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.3214 - accuracy: 0.5404 - val_loss: 1.3761 - val_accuracy: 0.5701
# Epoch 11/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.2614 - accuracy: 0.5695 - val_loss: 1.2873 - val_accuracy: 0.5736
# Epoch 12/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.2277 - accuracy: 0.5838 - val_loss: 1.2884 - val_accuracy: 0.5804
# Epoch 13/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.2021 - accuracy: 0.5913 - val_loss: 1.2337 - val_accuracy: 0.5953
# Epoch 14/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1728 - accuracy: 0.6099 - val_loss: 1.1764 - val_accuracy: 0.6245
# Epoch 15/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1536 - accuracy: 0.6069 - val_loss: 1.1792 - val_accuracy: 0.6079
# Epoch 16/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.1183 - accuracy: 0.6215 - val_loss: 1.1598 - val_accuracy: 0.6108
# Epoch 17/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.0891 - accuracy: 0.6418 - val_loss: 1.0867 - val_accuracy: 0.6611
# Epoch 18/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.0678 - accuracy: 0.6458 - val_loss: 1.1227 - val_accuracy: 0.6314
# Epoch 19/150
# 219/219 [==============================] - 2s 9ms/step - loss: 1.0614 - accuracy: 0.6478 - val_loss: 1.0389 - val_accuracy: 0.6709
# Epoch 20/150
# 219/219 [==============================] - 2s 8ms/step - loss: 1.0475 - accuracy: 0.6534 - val_loss: 0.9783 - val_accuracy: 0.7052
# Epoch 21/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9976 - accuracy: 0.6689 - val_loss: 0.9795 - val_accuracy: 0.6949
# Epoch 22/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9892 - accuracy: 0.6680 - val_loss: 0.9496 - val_accuracy: 0.6961
# Epoch 23/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.9543 - accuracy: 0.6799 - val_loss: 0.8807 - val_accuracy: 0.7378
# Epoch 24/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.9580 - accuracy: 0.6812 - val_loss: 0.8912 - val_accuracy: 0.7252
# Epoch 25/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.9284 - accuracy: 0.6872 - val_loss: 0.8833 - val_accuracy: 0.7230
# Epoch 26/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.9389 - accuracy: 0.6850 - val_loss: 0.8759 - val_accuracy: 0.7338
# Epoch 27/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.9338 - accuracy: 0.6880 - val_loss: 0.8694 - val_accuracy: 0.7481
# Epoch 28/150
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9069 - accuracy: 0.6995 - val_loss: 0.8660 - val_accuracy: 0.7355
# Epoch 29/150
# 219/219 [==============================] - 2s 11ms/step - loss: 0.8663 - accuracy: 0.7098 - val_loss: 0.7849 - val_accuracy: 0.7665
# Epoch 30/150
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8503 - accuracy: 0.7191 - val_loss: 0.8000 - val_accuracy: 0.7493
# Epoch 31/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.8462 - accuracy: 0.7194 - val_loss: 0.8029 - val_accuracy: 0.7659
# Epoch 32/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.8412 - accuracy: 0.7271 - val_loss: 0.8013 - val_accuracy: 0.7573
# Epoch 33/150
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8356 - accuracy: 0.7228 - val_loss: 0.8283 - val_accuracy: 0.7602
# Epoch 34/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7999 - accuracy: 0.7300 - val_loss: 0.7564 - val_accuracy: 0.7750
# Epoch 35/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.8223 - accuracy: 0.7331 - val_loss: 0.7837 - val_accuracy: 0.7710
# Epoch 36/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7668 - accuracy: 0.7463 - val_loss: 0.7358 - val_accuracy: 0.7836
# Epoch 37/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7934 - accuracy: 0.7370 - val_loss: 0.7070 - val_accuracy: 0.7831
# Epoch 38/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7944 - accuracy: 0.7364 - val_loss: 0.7501 - val_accuracy: 0.7859
# Epoch 39/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7467 - accuracy: 0.7513 - val_loss: 0.6988 - val_accuracy: 0.7968
# Epoch 40/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7370 - accuracy: 0.7566 - val_loss: 0.7035 - val_accuracy: 0.7796
# Epoch 41/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7309 - accuracy: 0.7631 - val_loss: 0.7083 - val_accuracy: 0.7779
# Epoch 42/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.7424 - accuracy: 0.7582 - val_loss: 0.7040 - val_accuracy: 0.7865
# Epoch 43/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7212 - accuracy: 0.7589 - val_loss: 0.6995 - val_accuracy: 0.7859
# Epoch 44/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6914 - accuracy: 0.7719 - val_loss: 0.6737 - val_accuracy: 0.7882
# Epoch 45/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.7026 - accuracy: 0.7696 - val_loss: 0.6866 - val_accuracy: 0.8002
# Epoch 46/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6749 - accuracy: 0.7712 - val_loss: 0.6645 - val_accuracy: 0.8037
# Epoch 47/150
# 219/219 [==============================] - 2s 10ms/step - loss: 0.6807 - accuracy: 0.7708 - val_loss: 0.6843 - val_accuracy: 0.7939
# Epoch 48/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6939 - accuracy: 0.7719 - val_loss: 0.6868 - val_accuracy: 0.7819
# Epoch 49/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6738 - accuracy: 0.7792 - val_loss: 0.6929 - val_accuracy: 0.7916
# Epoch 50/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6625 - accuracy: 0.7764 - val_loss: 0.6421 - val_accuracy: 0.8065
# Epoch 51/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6639 - accuracy: 0.7827 - val_loss: 0.6365 - val_accuracy: 0.8014
# Epoch 52/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6560 - accuracy: 0.7838 - val_loss: 0.6485 - val_accuracy: 0.8168
# Epoch 53/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6545 - accuracy: 0.7818 - val_loss: 0.6123 - val_accuracy: 0.8197
# Epoch 54/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6462 - accuracy: 0.7895 - val_loss: 0.6257 - val_accuracy: 0.8094
# Epoch 55/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6318 - accuracy: 0.7926 - val_loss: 0.5941 - val_accuracy: 0.8214
# Epoch 56/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6425 - accuracy: 0.7895 - val_loss: 0.6545 - val_accuracy: 0.7974
# Epoch 57/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6421 - accuracy: 0.7873 - val_loss: 0.6460 - val_accuracy: 0.7974
# Epoch 58/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6135 - accuracy: 0.8006 - val_loss: 0.5854 - val_accuracy: 0.8197
# Epoch 59/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6295 - accuracy: 0.7914 - val_loss: 0.6293 - val_accuracy: 0.7945
# Epoch 60/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6025 - accuracy: 0.8021 - val_loss: 0.6125 - val_accuracy: 0.8163
# Epoch 61/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6069 - accuracy: 0.8039 - val_loss: 0.5749 - val_accuracy: 0.8283
# Epoch 62/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6069 - accuracy: 0.7996 - val_loss: 0.6112 - val_accuracy: 0.8145
# Epoch 63/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5935 - accuracy: 0.8007 - val_loss: 0.5785 - val_accuracy: 0.8237
# Epoch 64/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6090 - accuracy: 0.7936 - val_loss: 0.6008 - val_accuracy: 0.8203
# Epoch 65/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.6220 - accuracy: 0.7940 - val_loss: 0.6050 - val_accuracy: 0.8180
# Epoch 66/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5761 - accuracy: 0.8102 - val_loss: 0.5736 - val_accuracy: 0.8300
# Epoch 67/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5581 - accuracy: 0.8120 - val_loss: 0.6016 - val_accuracy: 0.8157
# Epoch 68/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5632 - accuracy: 0.8126 - val_loss: 0.6139 - val_accuracy: 0.8008
# Epoch 69/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5653 - accuracy: 0.8169 - val_loss: 0.6064 - val_accuracy: 0.8037
# Epoch 70/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5904 - accuracy: 0.8062 - val_loss: 0.5683 - val_accuracy: 0.8443
# Epoch 71/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5578 - accuracy: 0.8152 - val_loss: 0.5654 - val_accuracy: 0.8306
# Epoch 72/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5600 - accuracy: 0.8156 - val_loss: 0.5673 - val_accuracy: 0.8449
# Epoch 73/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5564 - accuracy: 0.8169 - val_loss: 0.5838 - val_accuracy: 0.8283
# Epoch 74/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5520 - accuracy: 0.8195 - val_loss: 0.5648 - val_accuracy: 0.8374
# Epoch 75/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5596 - accuracy: 0.8146 - val_loss: 0.5704 - val_accuracy: 0.8317
# Epoch 76/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5329 - accuracy: 0.8222 - val_loss: 0.5718 - val_accuracy: 0.8489
# Epoch 77/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5572 - accuracy: 0.8162 - val_loss: 0.5497 - val_accuracy: 0.8489
# Epoch 78/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5317 - accuracy: 0.8230 - val_loss: 0.5677 - val_accuracy: 0.8288
# Epoch 79/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5515 - accuracy: 0.8155 - val_loss: 0.5504 - val_accuracy: 0.8432
# Epoch 80/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5305 - accuracy: 0.8268 - val_loss: 0.5584 - val_accuracy: 0.8472
# Epoch 81/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5291 - accuracy: 0.8190 - val_loss: 0.5600 - val_accuracy: 0.8437
# Epoch 82/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5275 - accuracy: 0.8269 - val_loss: 0.5569 - val_accuracy: 0.8266
# Epoch 83/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5186 - accuracy: 0.8228 - val_loss: 0.5328 - val_accuracy: 0.8506
# Epoch 84/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5230 - accuracy: 0.8246 - val_loss: 0.5594 - val_accuracy: 0.8403
# Epoch 85/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5265 - accuracy: 0.8246 - val_loss: 0.5481 - val_accuracy: 0.8472
# Epoch 86/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5000 - accuracy: 0.8309 - val_loss: 0.5374 - val_accuracy: 0.8443
# Epoch 87/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5089 - accuracy: 0.8342 - val_loss: 0.5531 - val_accuracy: 0.8409
# Epoch 88/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5087 - accuracy: 0.8319 - val_loss: 0.5110 - val_accuracy: 0.8517
# Epoch 89/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5117 - accuracy: 0.8356 - val_loss: 0.5938 - val_accuracy: 0.8105
# Epoch 90/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.5026 - accuracy: 0.8319 - val_loss: 0.5564 - val_accuracy: 0.8460
# Epoch 91/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4745 - accuracy: 0.8418 - val_loss: 0.5429 - val_accuracy: 0.8397
# Epoch 92/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4993 - accuracy: 0.8325 - val_loss: 0.5348 - val_accuracy: 0.8357
# Epoch 93/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4991 - accuracy: 0.8319 - val_loss: 0.5403 - val_accuracy: 0.8403
# Epoch 94/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4785 - accuracy: 0.8397 - val_loss: 0.5177 - val_accuracy: 0.8517
# Epoch 95/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5005 - accuracy: 0.8329 - val_loss: 0.5279 - val_accuracy: 0.8506
# Epoch 96/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4906 - accuracy: 0.8351 - val_loss: 0.5254 - val_accuracy: 0.8558
# Epoch 97/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4869 - accuracy: 0.8385 - val_loss: 0.5402 - val_accuracy: 0.8374
# Epoch 98/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4837 - accuracy: 0.8409 - val_loss: 0.5190 - val_accuracy: 0.8449
# Epoch 99/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5042 - accuracy: 0.8289 - val_loss: 0.5413 - val_accuracy: 0.8369
# Epoch 100/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5031 - accuracy: 0.8306 - val_loss: 0.5086 - val_accuracy: 0.8454
# Epoch 101/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5073 - accuracy: 0.8335 - val_loss: 0.4944 - val_accuracy: 0.8540
# Epoch 102/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4697 - accuracy: 0.8451 - val_loss: 0.4994 - val_accuracy: 0.8586
# Epoch 103/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4861 - accuracy: 0.8395 - val_loss: 0.5004 - val_accuracy: 0.8592
# Epoch 104/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4738 - accuracy: 0.8411 - val_loss: 0.4889 - val_accuracy: 0.8540
# Epoch 105/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4902 - accuracy: 0.8397 - val_loss: 0.4926 - val_accuracy: 0.8592
# Epoch 106/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4685 - accuracy: 0.8412 - val_loss: 0.5226 - val_accuracy: 0.8512
# Epoch 107/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4666 - accuracy: 0.8417 - val_loss: 0.5141 - val_accuracy: 0.8523
# Epoch 108/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4547 - accuracy: 0.8495 - val_loss: 0.5248 - val_accuracy: 0.8437
# Epoch 109/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4680 - accuracy: 0.8465 - val_loss: 0.4903 - val_accuracy: 0.8580
# Epoch 110/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4678 - accuracy: 0.8451 - val_loss: 0.4873 - val_accuracy: 0.8598
# Epoch 111/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4556 - accuracy: 0.8465 - val_loss: 0.4943 - val_accuracy: 0.8666
# Epoch 112/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4698 - accuracy: 0.8419 - val_loss: 0.5190 - val_accuracy: 0.8489
# Epoch 113/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4375 - accuracy: 0.8505 - val_loss: 0.4728 - val_accuracy: 0.8678
# Epoch 114/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4426 - accuracy: 0.8482 - val_loss: 0.4925 - val_accuracy: 0.8615
# Epoch 115/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4661 - accuracy: 0.8424 - val_loss: 0.4758 - val_accuracy: 0.8643
# Epoch 116/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4585 - accuracy: 0.8475 - val_loss: 0.4994 - val_accuracy: 0.8580
# Epoch 117/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4580 - accuracy: 0.8488 - val_loss: 0.4580 - val_accuracy: 0.8632
# Epoch 118/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4614 - accuracy: 0.8458 - val_loss: 0.4921 - val_accuracy: 0.8666
# Epoch 119/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4324 - accuracy: 0.8558 - val_loss: 0.4716 - val_accuracy: 0.8638
# Epoch 120/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4532 - accuracy: 0.8510 - val_loss: 0.4987 - val_accuracy: 0.8569
# Epoch 121/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4346 - accuracy: 0.8537 - val_loss: 0.4810 - val_accuracy: 0.8643
# Epoch 122/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4196 - accuracy: 0.8583 - val_loss: 0.4865 - val_accuracy: 0.8603
# Epoch 123/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4528 - accuracy: 0.8501 - val_loss: 0.4694 - val_accuracy: 0.8620
# Epoch 124/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4227 - accuracy: 0.8600 - val_loss: 0.4858 - val_accuracy: 0.8449
# Epoch 125/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4157 - accuracy: 0.8591 - val_loss: 0.4908 - val_accuracy: 0.8540
# Epoch 126/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4433 - accuracy: 0.8574 - val_loss: 0.4863 - val_accuracy: 0.8689
# Epoch 127/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4217 - accuracy: 0.8610 - val_loss: 0.4879 - val_accuracy: 0.8678
# Epoch 128/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4381 - accuracy: 0.8555 - val_loss: 0.4800 - val_accuracy: 0.8661
# Epoch 129/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4368 - accuracy: 0.8557 - val_loss: 0.4800 - val_accuracy: 0.8569
# Epoch 130/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4265 - accuracy: 0.8607 - val_loss: 0.4764 - val_accuracy: 0.8620
# Epoch 131/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4333 - accuracy: 0.8545 - val_loss: 0.4555 - val_accuracy: 0.8729
# Epoch 132/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4185 - accuracy: 0.8621 - val_loss: 0.5103 - val_accuracy: 0.8540
# Epoch 133/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4421 - accuracy: 0.8533 - val_loss: 0.4822 - val_accuracy: 0.8563
# Epoch 134/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4288 - accuracy: 0.8544 - val_loss: 0.5044 - val_accuracy: 0.8466
# Epoch 135/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4131 - accuracy: 0.8600 - val_loss: 0.5140 - val_accuracy: 0.8500
# Epoch 136/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4073 - accuracy: 0.8639 - val_loss: 0.4762 - val_accuracy: 0.8609
# Epoch 137/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4210 - accuracy: 0.8611 - val_loss: 0.4793 - val_accuracy: 0.8535
# Epoch 138/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4146 - accuracy: 0.8614 - val_loss: 0.4756 - val_accuracy: 0.8701
# Epoch 139/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4246 - accuracy: 0.8581 - val_loss: 0.5036 - val_accuracy: 0.8586
# Epoch 140/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4193 - accuracy: 0.8643 - val_loss: 0.4874 - val_accuracy: 0.8672
# Epoch 141/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4081 - accuracy: 0.8649 - val_loss: 0.4711 - val_accuracy: 0.8586
# Epoch 142/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3910 - accuracy: 0.8640 - val_loss: 0.4794 - val_accuracy: 0.8615
# Epoch 143/150
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4014 - accuracy: 0.8639 - val_loss: 0.4955 - val_accuracy: 0.8632
# Epoch 144/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4142 - accuracy: 0.8617 - val_loss: 0.5102 - val_accuracy: 0.8592
# Epoch 145/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3955 - accuracy: 0.8681 - val_loss: 0.5251 - val_accuracy: 0.8512
# Epoch 146/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4151 - accuracy: 0.8640 - val_loss: 0.4835 - val_accuracy: 0.8540
# Epoch 147/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3833 - accuracy: 0.8724 - val_loss: 0.4909 - val_accuracy: 0.8706
# Epoch 148/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4099 - accuracy: 0.8681 - val_loss: 0.4820 - val_accuracy: 0.8638
# Epoch 149/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.4090 - accuracy: 0.8650 - val_loss: 0.4779 - val_accuracy: 0.8638
# Epoch 150/150
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3914 - accuracy: 0.8674 - val_loss: 0.4774 - val_accuracy: 0.8558

# %%
model.save("urban_model")
# Out:
# 2022-05-30 00:19:46.363656: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: urban_model/assets

# %%
def extract_feature(file_name):
    audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    fea = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=50)
    scaled = np.mean(fea.T,axis=0)
    return np.array([scaled])

# %%
def print_prediction(file_name):
    pred_fea = extract_feature(file_name) 
    pred_vector = np.argmax(model.predict(pred_fea), axis=-1)
    pred_class = le.inverse_transform(pred_vector)
    print("The predicted class is:", pred_class[0], '\n')

# %%
file_name = '../input/urbansound8k/fold2/100652-3-0-2.wav'

print_prediction(file_name)

ipd.Audio(file_name)
# Out:
# The predicted class is: dog_bark
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_name = '../input/urbansound8k/fold6/101281-3-0-14.wav'

print_prediction(file_name)

ipd.Audio(file_name)
# Out:
# The predicted class is: dog_bark
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_name = '../input/urbansound8k/fold7/102853-8-0-2.wav'

print_prediction(file_name)

ipd.Audio(file_name)
# Out:
# The predicted class is: siren
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
